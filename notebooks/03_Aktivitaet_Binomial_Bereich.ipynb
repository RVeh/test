# %% [markdown]
# In dieser Aktivität betrachten wir **kumulative Wahrscheinlichkeiten**
# der Binomialverteilung.
# Die Grafik zeigt, wie sich Wahrscheinlichkeiten **aufsummieren**.

# %%
import setup_path
from lib.binomial import (BinomialModel, DistributionPlotStyle,
    TypographyStyle, plot_binomial_distribution_cdf,
)

# %%
model = BinomialModel(n=100, p=0.45)

style = DistributionPlotStyle(sigma_range=5.0, width=0.4,figsize=(8, 4))

typo = TypographyStyle()

plot_binomial_distribution_cdf(model, style, typo,
    k=56,
    direction="ge",
);
