# %% [markdown]
# In dieser Aktivität betrachten wir die Binomialverteilung als **reinen Wahrscheinlichkeitsraum**.
# Es werden **keine Tests** durchgeführt und **keine Entscheidungen** getroffen.
# Die Grafik dient als Arbeitsraum, um Ereignisse, Bereiche und Wahrscheinlichkeiten sichtbar zu machen.

# %%
import setup_path
from lib.binomial import (
    BinomialModel, 
    DistributionPlotStyle, 
    plot_binomial_distribution
)

# %%
model = BinomialModel(
    n=100, 
    p=0.45)

style=DistributionPlotStyle(
        sigma_range=5.0,
        bar_color = "tab:blue",
        width=0.4,
        grid = False,
        figsize = (6.5, 3.5),
)

plot_binomial_distribution(model, style)
